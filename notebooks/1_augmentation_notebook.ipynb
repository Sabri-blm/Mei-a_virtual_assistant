# %%
# doawload the requirements
# !pip install torchaudio-augmentations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21868 sha256=f8a91fbc9067cec17e980e07c009510aa328d4b5a86951ca44d8edd022d4c255
#   Stored in directory: /root/.cache/pip/wheels/b9/b2/05/f883527ffcb7f2ead5438a2c23439aa0c881eaa9a4c80256f4
# Successfully built julius
# ...

# %%
# mount your drive to extract our created wakeword data
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# unzip the data file
# !unzip /content/drive/MyDrive/wakeword_data.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/wakeword_data.zip
#   inflating: /content/wakeword_data/0.wave
#   inflating: /content/wakeword_data/1.wave
#   inflating: /content/wakeword_data/10.wave
#   inflating: /content/wakeword_data/100.wave
#   inflating: /content/wakeword_data/101.wave
#   inflating: /content/wakeword_data/102.wave
#   inflating: /content/wakeword_data/103.wave
#   inflating: /content/wakeword_data/104.wave
#   inflating: /content/wakeword_data/105.wave
#   inflating: /content/wakeword_data/106.wave
#   inflating: /content/wakeword_data/107.wave
#   inflating: /content/wakeword_data/108.wave
#   inflating: /content/wakeword_data/109.wave
#   inflating: /content/wakeword_data/11.wave
#   inflating: /content/wakeword_data/110.wave
#   inflating: /content/wakeword_data/111.wave
#   inflating: /content/wakeword_data/112.wave
#   inflating: /content/wakeword_data/113.wave
#   inflating: /content/wakeword_data/114.wave
#   inflating: /content/wakeword_data/115.wave
# ...

# %%
import os
os.makedirs("wakeword_data_aug_4smp")

# %%
# augment the data
# !python /content/augmentation_script.py -dir "/content/wakeword_data" -smp 4 -sdir "/content/wakeword_data_aug_4smp"
# Out:
#   0% 0/4 [00:00<?, ?it/s]
#   0% 0/301 [00:00<?, ?it/s]
#   0% 1/301 [00:00<04:52,  1.03it/s]
#   1% 2/301 [00:01<03:13,  1.54it/s]
#   1% 3/301 [00:02<03:13,  1.54it/s]
#   1% 4/301 [00:02<03:15,  1.52it/s]
#   2% 5/301 [00:03<03:05,  1.59it/s]
#   2% 6/301 [00:03<02:41,  1.83it/s]
#   2% 7/301 [00:04<02:39,  1.84it/s]
#   3% 8/301 [00:04<02:39,  1.83it/s]
#   3% 9/301 [00:05<02:41,  1.81it/s]
#   3% 10/301 [00:05<02:49,  1.72it/s]
#   4% 11/301 [00:06<02:38,  1.83it/s]
#   4% 12/301 [00:06<02:11,  2.19it/s]
#   4% 13/301 [00:07<02:21,  2.04it/s]
#   5% 14/301 [00:07<02:27,  1.95it/s]
#   5% 15/301 [00:07<01:52,  2.55it/s]
#   5% 16/301 [00:09<02:52,  1.65it/s]
#   6% 17/301 [00:09<02:52,  1.64it/s]
#   6% 18/301 [00:10<02:31,  1.87it/s]
#   6% 19/301 [00:10<02:41,  1.74it/s]
#   7% 20/301 [00:11<02:24,  1.95it/s]
#   7% 21/301 [00:11<02:07,  2.19it/s]
#   7% 22/301 [00:11<01:57,  2.38it/s]
#   8% 23/301 [00:12<01:45,  2.62it/s]
#   8% 24/301 [00:12<01:45,  2.63it/s]
# ...

# %%
# Check how many samples are in the wakeword directory
import os

len(os.listdir("/content/wakeword_data_aug_4smp"))
# Out:
# 4816

# %%
# how much it is supposed to be the augmeneted - changed the 4 with your -smp value
301*4*4 + 301
# Out:
# 5117

# %%
import shutil
import os

source_directory = "/content/wakeword_data"
destination_directory = "/content/wakeword_data_aug_4smp"

# Get a list of all files in the source directory
file_list = os.listdir(source_directory)

# Loop through the files and copy them to the destination directory
for file_name in file_list:
    source_path = os.path.join(source_directory, file_name)
    destination_path = os.path.join(destination_directory, file_name)
    shutil.copy(source_path, destination_path)

# %%
import os

len(os.listdir("/content/wakeword_data_aug_4smp"))
# Out:
# 5117

# %%
# !zip -r wakeword_data_aug_4smp.zip /content/wakeword_data_aug_4smp
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   adding: content/wakeword_data_aug_4smp/config0_trans1_230.wav (deflated 63%)
#   adding: content/wakeword_data_aug_4smp/config1_trans1_37.wav (deflated 27%)
#   adding: content/wakeword_data_aug_4smp/config0_trans0_25.wav (deflated 43%)
#   adding: content/wakeword_data_aug_4smp/config2_trans2_296.wav (deflated 32%)
#   adding: content/wakeword_data_aug_4smp/config0_trans3_68.wav (deflated 41%)
#   adding: content/wakeword_data_aug_4smp/171.wav (deflated 50%)
#   adding: content/wakeword_data_aug_4smp/config1_trans3_129.wav (deflated 37%)
#   adding: content/wakeword_data_aug_4smp/config3_trans1_147.wav (deflated 34%)
#   adding: content/wakeword_data_aug_4smp/config1_trans3_94.wav (deflated 35%)
#   adding: content/wakeword_data_aug_4smp/config2_trans0_28.wav (deflated 42%)
#   adding: content/wakeword_data_aug_4smp/config0_trans3_178.wav (deflated 39%)
# ...

# %%
# !cp "/content/wakeword_data_aug_4smp.zip" "/content/drive/MyDrive"

# %%
drive.flush_and_unmount()

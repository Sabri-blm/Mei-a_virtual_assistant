# %% [markdown]
# ## Common voice data

# %%
import os

os.makedirs("/content/common_voice")
# %cd common_voice
# Out:
# /content/common_voice

# %%
# the 23/04/2023 data 2.11Gb
# !wget -c "https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-13.0-delta-2023-03-09/cv-corpus-13.0-delta-2023-03-09-en.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3M6UQN3GN%2F20230903%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20230903T130149Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEGYaDFdj4a7wIr6v2FMwZyKSBCJLZYFW615L%2FOqV%2BC2RUClRoxS0THYWUX4hhcjB7KyhFsQWK0abk%2Fjcl6fRR%2FaTE2EzjbgopPH1HuRPxSJm6BZhmJT7sdHnB6FWVgIen8q3m%2FLk8hEbzUPvfiTId4XWz%2FTm5Cl1SnPm%2BE4%2FL306Zu9H%2F8x2KHswGFpIZqz2v1%2BCbFkfycwF04y%2B4RbMHvpDHTjnRr4VOAXV4lthpbOuVn6DLVuUyTfsicI2uaCWziq7yAxr7inwO2vPqczTQse1oJ8BsuXfTa2r2ra6xdwOrnQmOp5Oc1UWFOSCbGJ9s%2FC233Mi1oqdfe5r58SXC5ZAoabodjniTifJjqsjpPtEzqwAapqo4e4Lur5zBVB4d%2BnRhuneQ183ol4DCkjERGc%2FbEQYhVQb2zagviZvfTBd21ReIuzlgelLCLmlKPYZd1c43xsOgV9fxR%2BunbrBQdG%2Bxy9B4cqQ2qJPlL6TFAd%2BKSMLOLzPD3yniHSvO%2FEBuTXZhoErWu%2BYA%2BzA3iCOYLzAxpTwyAlpZ9wnZgLxYDRlm6IyXMUShoq7lZvLPETeJs72vaG%2BjV2O0N%2F4ue9xPlhon8Thf4kOe335ZotAjeF4%2FsPkqHyirAbt7OKaTQCUMeFEjbcWapEl9TLOIqPoHQMP8VEFCta%2BmlIsfuxWAXEaqAngB870jVj5LDJNGzYyeRnhZFrvGBnGdOJmg8rpd2GxrEOSKPqA0qcGMipz1hOrJcyX6Jjauv%2BEtCmPa2Km3Z2viaPEFzLrhtpsXTV1iKkvj2mwhMs%3D&X-Amz-Signature=739c292d2758901eb4491c1cef337955438ab6b5b31f578fd5ed9027b5c47f0c&X-Amz-SignedHeaders=host" -O "en.tar"
# !tar -xzf en.tar
# !rm en.tar
# Out:
# --2023-09-03 13:02:17--  https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-13.0-delta-2023-03-09/cv-corpus-13.0-delta-2023-03-09-en.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3M6UQN3GN%2F20230903%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20230903T130149Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEGYaDFdj4a7wIr6v2FMwZyKSBCJLZYFW615L%2FOqV%2BC2RUClRoxS0THYWUX4hhcjB7KyhFsQWK0abk%2Fjcl6fRR%2FaTE2EzjbgopPH1HuRPxSJm6BZhmJT7sdHnB6FWVgIen8q3m%2FLk8hEbzUPvfiTId4XWz%2FTm5Cl1SnPm%2BE4%2FL306Zu9H%2F8x2KHswGFpIZqz2v1%2BCbFkfycwF04y%2B4RbMHvpDHTjnRr4VOAXV4lthpbOuVn6DLVuUyTfsicI2uaCWziq7yAxr7inwO2vPqczTQse1oJ8BsuXfTa2r2ra6xdwOrnQmOp5Oc1UWFOSCbGJ9s%2FC233Mi1oqdfe5r58SXC5ZAoabodjniTifJjqsjpPtEzqwAapqo4e4Lur5zBVB4d%2BnRhuneQ183ol4DCkjERGc%2FbEQYhVQb2zagviZvfTBd21ReIuzlgelLCLmlKPYZd1c43xsOgV9fxR%2BunbrBQdG%2Bxy9B4cqQ2qJPlL6TFAd%2BKSMLOLzPD3yniHSvO%2FEBuTXZhoErWu%2BYA%2BzA3iCOYLzAxpTwyAlpZ9wnZgLxYDRlm6IyXMUShoq7lZvLPETeJs72vaG%2BjV2
# ...

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# ## wakeword data

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/wakeword_data_aug_4smp.zip -d /
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/wakeword_data_aug_4smp/config0_trans2_111.wav
#   inflating: /content/wakeword_data_aug_4smp/config0_trans1_230.wav
#   inflating: /content/wakeword_data_aug_4smp/config1_trans1_37.wav
#   inflating: /content/wakeword_data_aug_4smp/config0_trans0_25.wav
#   inflating: /content/wakeword_data_aug_4smp/config2_trans2_296.wav
#   inflating: /content/wakeword_data_aug_4smp/config0_trans3_68.wav
#   inflating: /content/wakeword_data_aug_4smp/171.wav
#   inflating: /content/wakeword_data_aug_4smp/config1_trans3_129.wav
#   inflating: /content/wakeword_data_aug_4smp/config3_trans1_147.wav
#   inflating: /content/wakeword_data_aug_4smp/config1_trans3_94.wav
#   inflating: /content/wakeword_data_aug_4smp/config2_trans0_28.wav
#   inflating: /content/wakeword_data_aug_4smp/config0_trans3_178.wav
#   inflating: /content/wakeword_data_aug_4smp/config1_trans2_184.wav
# ...

# %%
import os

len(os.listdir("/content/wakeword_data_aug_4smp"))
# Out:
# 5117

# %%
# !cp "/content/drive/MyDrive/wakeword_4smp.csv" "/content"

# %% [markdown]
# ## Building dataset class

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# ...

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchaudio
import torch
import torch.nn as nn
import pandas as pd

# %%
class WakeWordDataset(Dataset):
  def __init__(self, csv, sample_rate, nbr_samples, device, transformations):
    #super.__init__()
    self.csv = pd.read_csv(csv)
    self.sample_rate = sample_rate
    self.nbr_samples = nbr_samples
    self.device = device
    self.transformations = transformations


  def __len__(self):
    return len(self.csv)

  def __getitem__(self, i):
    audio, sr = torchaudio.load(self.csv.iloc[i, 0])
    label = self.csv.iloc[i, 1]

    audio = audio.to(self.device)
    label = torch.tensor(label).to(self.device)
    # Make sure that all audio's have the same sample_rate
    audio = self._resample_if_necessary(audio, sr)
    # Make sure every audio have the same channels .ie 1
    audio = self._mix_down_if_necessary(audio)
    # If the audio is longer than the wanted length, cut it down
    audio = self._cut_down_if_necessary(audio)
    # If the audio is shorter, fill it up
    audio = self._right_padding_if_necessary(audio)
    # Lastly create the Mel-Spectrogram
    audio = self.transformations(audio)
    # we remove the channel dimention from (nbr_channels, n_mels, time) -> (n_mels, time)
    audio = audio.squeeze(dim=0)
    # now we transpose from (n_mels, time) -> (time, n_mels) for the input of LSTM
    audio = torch.transpose(audio, 0, 1)
    return audio, label

  def _resample_if_necessary(self, audio, sr):
    if sr != self.sample_rate:
      resampler = torchaudio.transforms.Resample(sr, self.sample_rate).to(self.device)
      audio = resampler(audio)
    return audio

  def _mix_down_if_necessary(self, audio):
    if audio.shape[0] > 1:
      audio = torch.mean(audio, dim=0, keepdim=True)
    return audio

  def _cut_down_if_necessary(self, audio):
    if audio.shape[1] > self.nbr_samples:
      audio = audio[:, :self.nbr_samples]
    return audio

  def _right_padding_if_necessary(self, audio):
    if audio.shape[1] < self.nbr_samples:
      left_padding = (0, self.nbr_samples - audio.shape[1])
      audio = torch.nn.functional.pad(audio, left_padding)
    return audio

# %%
if torch.cuda.is_available():
  device = "cuda"
else:
  device = "cpu"

SAMPLE_RATE= 48000
NBR_SAMPLES = 240000

print(f"device is {device}")

mel_spectrogram = torchaudio.transforms.MelSpectrogram(sample_rate=SAMPLE_RATE,
                                                       n_fft=1024,
                                                       hop_length=512, # half the frame_size n_fft
                                                       n_mels=64)

transform = nn.Sequential(mel_spectrogram)

data = WakeWordDataset(csv = "/content/wakeword_4smp.csv",
                    sample_rate = SAMPLE_RATE,
                    nbr_samples = NBR_SAMPLES,
                    device = device,
                    transformations = transform.to(device))
# Out:
# device is cuda

# %%
audio, label = data[0]

# %%
# the shape represent (nbr_of_channels, n_mels, time)
audio.shape
# Out:
# torch.Size([469, 64])

# %%
loader = DataLoader(data, batch_size=16)

dat, labelll = next(iter(loader))
print(dat.shape)
print(labelll)
# Out:
# torch.Size([16, 469, 64])
# tensor([1, 1, 1, 1, 0, 0, 1, 0, 0, 1, 0, 1, 0, 1, 1, 1], device='cuda:0')

# %% [markdown]
# ## Model Building

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

# %%
class LSTMmodel(nn.Module):
  def __init__(self, hidden_size, input_size, nbr_layers, nbr_classes, dropouts, device):
    super(LSTMmodel, self).__init__()
    self.hidden_size = hidden_size
    self.input_size = input_size
    self.nbr_layers = nbr_layers
    self.device = device

    self.lstm = nn.LSTM(input_size=self.input_size,
                        hidden_size=self.hidden_size,
                        num_layers=self.nbr_layers,
                        batch_first=True,
                        dropout = dropouts)
    # after the batch first the shape of input and output should be (batch, sequence==time, features)
    self.fc = nn.Linear(self.hidden_size, nbr_classes)
    self.relu = nn.ReLU()
    self.out_put = nn.Softmax(dim=1)

  def forward(self, x):
    # x.shape[0] == batch_size
    hidden_state = torch.zeros(self.nbr_layers, x.shape[0], self.hidden_size).to(self.device)
    cell_state = torch.zeros(self.nbr_layers, x.shape[0], self.hidden_size).to(self.device)

    out, _ = self.lstm(x, (hidden_state.detach(), cell_state.detach()))
    out = self.relu(out)
    out = self.fc(out[:, -1, :])
    #print(out)
    #out = self.out_put(out)

    return out

# %%
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

print(f"device is {device}")

network = LSTMmodel(hidden_size = 128,
                    input_size = 64,
                    nbr_layers = 1,
                    device = device,
                    nbr_classes = 2,
                    dropouts = 0.2)

summary(network, input_size=(1,469, 64)) # (model, shape of melspectogram)
# Out:
# device is cuda
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# LSTMmodel                                [1, 2]                    --
# ├─LSTM: 1-1                              [1, 469, 128]             99,328
# ├─ReLU: 1-2                              [1, 469, 128]             --
# ├─Linear: 1-3                            [1, 2]                    258
# ...
# Total params: 99,586
# Trainable params: 99,586
# Non-trainable params: 0
# Total mult-adds (M): 46.59
# ...
# Input size (MB): 0.12
# Forward/backward pass size (MB): 0.48
# Params size (MB): 0.40
# Estimated Total Size (MB): 1.00
# ...

# %%
from sklearn.metrics import accuracy_score
with torch.no_grad():
  preds = network(dat)
  print(preds)
  print("-------------------------------")
  print("-------------------------------")
  print("-------------------------------")
# Out:
# tensor([[-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0642,  0.0562],
#         [-0.0645,  0.0565],
#         [-0.0250,  0.0861],
#         [-0.0645,  0.0565],
#         [-0.0190,  0.0766],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0679,  0.0406],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565],
#         [-0.0645,  0.0565]], device='cuda:0')
# -------------------------------
# -------------------------------
# -------------------------------

# %%
def create_data_loader(train_data, batch_size):
  return DataLoader(train_data, batch_size=batch_size)

def train_single_epoch(model, data_loader, loss_fn, optimizer, device):
  for input, label in data_loader:
    input, label = input.to(device), label.to(device)
    pred = model(input)
    loss = loss_fn(pred, label)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
  print(f"loss: {loss.item()}")

def Train(model, data_loader, loss_fn, optimizer, epoch, device):
  for i in range(epoch):
    print(f"epoch: {i+1}")
    train_single_epoch(model, data_loader, loss_fn, optimizer, device)
    print("------------------------------")
  print("Training is finished")

# %%
Batch_size = 256
Epoch = 5
Learning_rate = 0.01

network = network.to(device)

train_loader = create_data_loader(data, Batch_size)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(network.parameters(), lr=Learning_rate)

Train(network, train_loader, loss_fn, optimizer, Epoch, device)
# Out:
# epoch: 1
# loss: 0.10562163591384888
# ------------------------------
# epoch: 2
# loss: 0.01604146882891655
# ------------------------------
# epoch: 3
# loss: 0.010333789512515068
# ------------------------------
# epoch: 4
# loss: 0.007512761279940605
# ------------------------------
# epoch: 5
# loss: 0.0035917109344154596
# ------------------------------
# Training is finished

# %% [markdown]
# ## Testing

# %%
import os

os.makedirs("/content/test_common_voice")
# %cd test_common_voice
# Out:
# /content/test_common_voice

# %%
# the 11/01/2022 910.18 Mb
# !wget -c "https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-11.0-delta-2022-09-21/cv-corpus-11.0-delta-2022-09-21-en.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3KNR7YAYH%2F20230903%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20230903T150711Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEGgaDOkW8U%2Bt%2Bhn4iAQIKiKSBFWG8RuQjA%2F0A6GcCRtiyk9A%2F8SgIVG8zvx42%2BUlZ8lq1Y04k2MhXlLHDeCxETUr36OzhzkEZFhfwDjvClK6bGNu5ld988ETfuMqtOCuadHBXucy4reumO0cg23gqKOWaoBiSELs%2B5bnIpTRcYwcM537mwBJqT7Dim7t3eUgBHcN8Ff0sqxMZ6rudUYwtYJ2uplnAXyWgkXGKcyvW0pUjDHQk7M62NMxcdiOCNkcLeB%2Begnm5z9Ed9w6lV0vTVfdKH7ke1Bc%2BJXnhmttg4%2F7oJb3zL%2B0siAIuLk4xgZDERdY8%2FQ%2BfT4OfHvtJbCVd90myCZXL8QSJemZPOrv%2BRXYwmYsOtR4rvvqcvC7fAWHokyedwiIupiBmWxefKqWV2P%2FVawgp%2BhNF3CzQomUfP6%2BqmiM0mcm2%2F00IK9a%2BmzRLmpWjH1QQ4UDj5To9p1Q5qjlovuw7GvIPbIaHyjuq1X1HFjG6jYi2Gm08OGdYLYbVopPQgoDDiNl1rZdMFaggEZCaXslwuev115OMmGtr1mFo2NoxCtPMRamxdV%2BAksNrZfW7PcRjBf8rxYy7p3y2PUcyp2oUgAr1QoZeg09n90jTqKrX30qtSOU7OBE3xJZseIqT53GPwxnPSb4MVxxE5s5mNPi1rWk3WgFRmn%2BYKly7BFzqIy5zvW6ni7Dc%2FH61fx%2BSMG%2BteaqeJeMXvFD9rs6dpUhKJm20qcGMipuyGeSBfanftyPid572DIuQwiWcYQkOhI3%2Fq9RVfMlplYYbZbx7QOgihM%3D&X-Amz-Signature=6a5d862552202db97b89f4bd5074b06bfb4b4384b4f8ac769724ff977b002195&X-Amz-SignedHeaders=host" -O "en.tar"
# !tar -xzf en.tar
# !rm en.tar
# Out:
# --2023-09-03 15:09:18--  https://mozilla-common-voice-datasets.s3.dualstack.us-west-2.amazonaws.com/cv-corpus-11.0-delta-2022-09-21/cv-corpus-11.0-delta-2022-09-21-en.tar.gz?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIAQ3GQRTO3KNR7YAYH%2F20230903%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20230903T150711Z&X-Amz-Expires=43200&X-Amz-Security-Token=FwoGZXIvYXdzEGgaDOkW8U%2Bt%2Bhn4iAQIKiKSBFWG8RuQjA%2F0A6GcCRtiyk9A%2F8SgIVG8zvx42%2BUlZ8lq1Y04k2MhXlLHDeCxETUr36OzhzkEZFhfwDjvClK6bGNu5ld988ETfuMqtOCuadHBXucy4reumO0cg23gqKOWaoBiSELs%2B5bnIpTRcYwcM537mwBJqT7Dim7t3eUgBHcN8Ff0sqxMZ6rudUYwtYJ2uplnAXyWgkXGKcyvW0pUjDHQk7M62NMxcdiOCNkcLeB%2Begnm5z9Ed9w6lV0vTVfdKH7ke1Bc%2BJXnhmttg4%2F7oJb3zL%2B0siAIuLk4xgZDERdY8%2FQ%2BfT4OfHvtJbCVd90myCZXL8QSJemZPOrv%2BRXYwmYsOtR4rvvqcvC7fAWHokyedwiIupiBmWxefKqWV2P%2FVawgp%2BhNF3CzQomUfP6%2BqmiM0mcm2%2F00IK9a%2BmzRLmpWjH1QQ4UDj5To9p1Q5qjlovuw7GvIPbIaHyjuq1X1HFjG6jYi2Gm08OGdYLYbVopPQgoDDiNl1rZdMFaggEZCaXslwuev115OMmGtr1mFo2NoxCtPMRamxdV%2BAksNrZfW7PcRjBf8rxY
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !unzip /content/wakeword_test_data.zip -d /content
# Out:
# Archive:  /content/wakeword_test_data.zip
#   inflating: /content/wakeword_test_data/0.wave
#   inflating: /content/wakeword_test_data/1.wave
#   inflating: /content/wakeword_test_data/10.wave
#   inflating: /content/wakeword_test_data/100.wave
#   inflating: /content/wakeword_test_data/101.wave
#   inflating: /content/wakeword_test_data/102.wave
#   inflating: /content/wakeword_test_data/103.wave
#   inflating: /content/wakeword_test_data/104.wave
#   inflating: /content/wakeword_test_data/105.wave
#   inflating: /content/wakeword_test_data/106.wave
#   inflating: /content/wakeword_test_data/107.wave
#   inflating: /content/wakeword_test_data/108.wave
#   inflating: /content/wakeword_test_data/109.wave
#   inflating: /content/wakeword_test_data/11.wave
#   inflating: /content/wakeword_test_data/110.wave
#   inflating: /content/wakeword_test_data/111.wave
#   inflating: /content/wakeword_test_data/112.wave
#   inflating: /content/wakeword_test_data/113.wave
# ...

# %%
data = WakeWordDataset(csv = "/content/drive/MyDrive/test_data_wakeword.csv",
                    sample_rate = SAMPLE_RATE,
                    nbr_samples = NBR_SAMPLES,
                    device = device,
                    transformations = transform.to(device))
# what is needed to be done:
# lstm input need to be (batches, sequence==time, input_size == features == n_mels) so i should permute the input
loader = DataLoader(data, batch_size=16)

dat, labelll = next(iter(loader))
print(dat.shape)
print(labelll)
# Out:
# torch.Size([16, 469, 64])
# tensor([0, 0, 1, 0, 1, 1, 1, 0, 0, 0, 0, 1, 1, 0, 1, 1], device='cuda:0')

# %%
preds = torch.tensor([]).to(device)
labels = torch.tensor([]).to(device)
with torch.no_grad():
  network.eval()
  for input, label in loader:
      input, label = input.to(device), label.to(device)
      pred = network(input)

      preds = torch.cat((preds, pred.argmax(1)))
      labels = torch.cat((labels, label))

# %%
from sklearn.metrics import accuracy_score

accuracy_score(preds.cpu(), labels.cpu())
# Out:
# 0.956953642384106

# %%
model_scripted = torch.jit.script(network) # Export to TorchScript
model_scripted.save('wakeword_model.pt') # Save

# %%
# !cp "/content/wakeword_model.pt" "/content/drive/MyDrive"
